# %%
import pandas as pd
import ast

# %%
df=pd.read_excel("chennai_cars.xlsx")
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
df["new_car_specs"][0]
# Out:
# "{'heading': 'Specifications', 'top': [{'key': 'Engine', 'value': '998 CC'}, {'key': 'Max Power', 'value': '118.36bhp'}, {'key': 'Torque', 'value': '172nm'}, {'key': 'Wheel Size', 'value': '16'}, {'key': 'Seats', 'value': '5'}], 'data': [{'heading': 'Engine and Transmission', 'subHeading': 'Engine', 'list': [{'key': 'Color', 'value': 'Black'}, {'key': 'Engine Type', 'value': 'Smartstream G1.0 T - GDi'}, {'key': 'Displacement', 'value': '998'}, {'key': 'Max Power', 'value': '118.36bhp@6000rpm'}, {'key': 'Max Torque', 'value': '172nm@1500-4000rpm'}, {'key': 'No of Cylinder', 'value': 3}, {'key': 'Values per Cylinder', 'value': 4}, {'key': 'Fuel Suppy System', 'value': 'GDi'}, {'key': 'Turbo Charger', 'value': 'Yes'}]}, {'heading': 'Dimensions & Capacity', 'subHeading': 'Dimensions', 'list': [{'key': 'Length', 'value': '3995mm'}, {'key': 'Width', 'value': '1790'}, {'key': 'Height', 'value': '1642'}, {'key': 'Wheel Base', 'value': '2500'}, {'key': 'Kerb Weight', 'value': '1465'}]}, {'hea
# ...

# %%
df["new_car_specs"][1]
# Out:
# "{'heading': 'Specifications', 'top': [{'key': 'Mileage', 'value': '15.37 kmpl'}, {'key': 'Engine', 'value': '1196 CC'}, {'key': 'Max Power', 'value': '73bhp'}, {'key': 'Torque', 'value': '101Nm'}, {'key': 'Seats', 'value': '7'}], 'data': [{'heading': 'Engine and Transmission', 'subHeading': 'Engine', 'list': [{'key': 'Color', 'value': 'Grey'}, {'key': 'Engine Type', 'value': 'In-Line Engine'}, {'key': 'Displacement', 'value': '1196'}, {'key': 'Max Power', 'value': '73bhp@6000rpm'}, {'key': 'Max Torque', 'value': '101Nm@3000rpm'}, {'key': 'No of Cylinder', 'value': 4}, {'key': 'Values per Cylinder', 'value': 4}, {'key': 'Value Configuration', 'value': 'DOHC'}, {'key': 'Fuel Suppy System', 'value': 'MPFi'}, {'key': 'Compression Ratio', 'value': '9.9:1'}, {'key': 'Turbo Charger', 'value': 'No'}, {'key': 'Super Charger', 'value': 'No'}]}, {'heading': 'Dimensions & Capacity', 'subHeading': 'Dimensions', 'list': [{'key': 'Length', 'value': '3675mm'}, {'key': 'Width', 'value': '1475mm'}, {
# ...

# %%
# Your string
data_str =df["new_car_feature"][0]

# Convert the string to a dictionary
data_dict = ast.literal_eval(data_str)
temp = data_dict["data"]
for i in temp:
    print(i["heading"])
# Out:
# Comfort & Convenience
# Interior
# Exterior
# Safety
# Entertainment & Communication

# %% [markdown]
# # new_car_feature

# %%
empty_list=[]
for i in df['new_car_feature']:
    temp = ast.literal_eval(i)
    temp = temp["data"]
    emptylist={}
    emptylist["total car features"]= len(temp)
    for j in temp:
        emptylist[j["heading"]]= "yes"
    empty_list.append(pd.DataFrame([emptylist]))

# %%
empty_list
# Out:
# [   total car features Comfort & Convenience Interior Exterior Safety  \
#  0                   5                   yes      yes      yes    yes
#
#    Entertainment & Communication
#  0                           yes  ,
#     total car features Comfort & Convenience Interior Exterior Safety
#  0                   4                   yes      yes      yes    yes,
#     total car features Comfort & Convenience Interior Exterior Safety  \
#  0                   5                   yes      yes      yes    yes
#
#    Entertainment & Communication
#  0                           yes  ,
#     total car features Comfort & Convenience Interior Exterior Safety  \
#  0                   5                   yes      yes      yes    yes
#
#    Entertainment & Communication
#  0                           yes  ,
#     total car features Comfort & Convenience Interior Exterior Safety  \
#  0                   5                   yes      yes      yes    yes
#
#    Entertainment & Communication
# ...

# %%
new_car_feature = pd.concat(empty_list, ignore_index=True)

# %%
new_car_feature
# Out:
#       total car features Comfort & Convenience Interior Exterior Safety  \
# 0                      5                   yes      yes      yes    yes
# 1                      4                   yes      yes      yes    yes
# 2                      5                   yes      yes      yes    yes
# 3                      5                   yes      yes      yes    yes
# 4                      5                   yes      yes      yes    yes
# ...                  ...                   ...      ...      ...    ...
# 1414                   5                   yes      yes      yes    yes
# 1415                   5                   yes      yes      yes    yes
# 1416                   5                   yes      yes      yes    yes
# 1417                   5                   yes      yes      yes    yes
# 1418                   5                   yes      yes      yes    yes
#
#      Entertainment & Communication
# 0                              yes
# ...

# %%
new_car_feature.fillna("no",inplace=True)

# %%
new_car_feature
# Out:
#       total car features Comfort & Convenience Interior Exterior Safety  \
# 0                      5                   yes      yes      yes    yes
# 1                      4                   yes      yes      yes    yes
# 2                      5                   yes      yes      yes    yes
# 3                      5                   yes      yes      yes    yes
# 4                      5                   yes      yes      yes    yes
# ...                  ...                   ...      ...      ...    ...
# 1414                   5                   yes      yes      yes    yes
# 1415                   5                   yes      yes      yes    yes
# 1416                   5                   yes      yes      yes    yes
# 1417                   5                   yes      yes      yes    yes
# 1418                   5                   yes      yes      yes    yes
#
#      Entertainment & Communication
# 0                              yes
# ...

# %% [markdown]
# # new_car_specs

# %%
specs_list=[]

for i in df["new_car_specs"]:
    temp = ast.literal_eval(i)
    emptylist={}
   # print(temp)
    for j in temp["top"]:
        #print(j)
        emptylist[j['key']]= j['value']
        
    for j in temp["data"]:
        #print(j)
        for k in j["list"]:
            #print(k)
            emptylist[k['key']]= k['value']
    #print(emptylist)

    
    specs_list.append(pd.DataFrame([emptylist]))

# %%
specs_list
# Out:
# [   Color  Engine Type Displacement         Max Power    Max Torque  \
#  0  White  K10B Engine          998  67.04bhp@6000rpm  90Nm@3500rpm
#
#     No of Cylinder  Values per Cylinder Value Configuration Fuel Suppy System  \
#  0               3                    4                DOHC              MPFi
#
#    BoreX Stroke  ... Seating Capacity Steering Type Turning Radius  \
#  0   73 X 82 mm  ...                5         Power     4.7 metres
#
#    Front Brake Type Rear Brake Type Top Speed   Acceleration         Tyre Type  \
#  0  Ventilated Disc            Drum  150 Kmph  15.05 Seconds  Tubeless, Radial
#
#    No Door Numbers Cargo Volumn
#  0               5   235-litres
#
#  [1 rows x 33 columns],
#     Color           Engine Type Displacement          Max Power     Max Torque  \
#  0  White  Ti-VCT Petrol Engine         1497  121.31bhp@6500rpm  150Nm@4500rpm
#
#     No of Cylinder  Values per Cylinder Value Configuration Fuel Suppy System  \
# ...

# %%
new_car_specs = pd.concat(specs_list, ignore_index=True)

# %%
new_car_specs
# Out:
#        Engine          Max Power   Torque Wheel Size Seats   Color  \
# 0      998 CC  118.36bhp@6000rpm    172nm         16     5   Black
# 1     1196 CC      73bhp@6000rpm    101Nm        NaN     7    Grey
# 2      999 CC   98.63bhp@5000rpm    160Nm         16     5  Others
# 3     1086 CC   68.05bhp@5500rpm  99.04Nm        NaN     5  Silver
# 4     1199 CC    88.7bhp@6000rpm    110Nm         15     5  Others
# ...       ...                ...      ...        ...   ...     ...
# 1414  1197 CC   81.80bhp@6000rpm    113Nm        NaN     5    Blue
# 1415  1461 CC    83.8bhp@3750rpm    200Nm         16     5  Orange
# 1416  1198 CC   108.5bhp@5000rpm    170Nm         16     5   White
# 1417  1968 CC     141bhp@4000rpm    340Nm         18     5    Grey
# 1418  1995 CC     188bhp@4000rpm    400Nm         18     5   White
#
#                                    Engine Type Displacement  \
# 0                     Smartstream G1.0 T - GDi          998
# ...

# %% [markdown]
# # new_car_overview

# %%
features_list = []

# Process top features
for i in df["new_car_overview"]:
    temp = ast.literal_eval(i)
    temp=temp["top"]
    emptylist={}
    
    for j in temp:
        emptylist[j['key']]= j['value']
    print(emptylist)
    features_list.append(pd.DataFrame([emptylist]))

# Create a DataFrame from the features list
#features_df = pd.DataFrame(features_list)

# Display the resulting DataFrame
features_list
# Out:
# {'Registration Year': '2022', 'Insurance Validity': 'Third Party insurance', 'Fuel Type': 'Petrol', 'Seats': '5 Seats', 'Kms Driven': '20,000 Kms', 'RTO': 'TS04', 'Ownership': 'First Owner', 'Engine Displacement': '999 cc', 'Transmission': 'Automatic', 'Year of Manufacture': 2022}
# {'Registration Year': 'Oct 2014', 'Insurance Validity': 'Third Party insurance', 'Fuel Type': 'Petrol', 'Seats': '5 Seats', 'Kms Driven': '85,582 Kms', 'RTO': 'TS09', 'Ownership': 'Second Owner', 'Engine Displacement': '814 cc', 'Transmission': 'Manual', 'Year of Manufacture': 2014}
# {'Registration Year': '2023', 'Insurance Validity': 'Third Party insurance', 'Fuel Type': 'Petrol', 'Seats': '5 Seats', 'Kms Driven': '10,000 Kms', 'Ownership': 'First Owner', 'Engine Displacement': '1197 cc', 'Transmission': 'Manual', 'Year of Manufacture': 2023}
# ...

# %%
features_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 features_list
#
# NameError: name 'features_list' is not defined

# %%
new_car_overview = pd.concat(features_list, ignore_index=True)

# %%
new_car_overview
# Out:
#      Registration Year     Insurance Validity Fuel Type    Seats  Kms Driven  \
# 0                 2022  Third Party insurance    Petrol  5 Seats  20,000 Kms
# 1             Feb 2015          Comprehensive    Petrol  7 Seats  20,687 Kms
# 2                 2021  Third Party insurance    Petrol  5 Seats  30,000 Kms
# 3             May 2015          Comprehensive    Petrol  5 Seats  59,247 Kms
# 4                 2015  Third Party insurance    Petrol  5 Seats  50,000 Kms
# ...                ...                    ...       ...      ...         ...
# 1414          Jun 2018  Third Party insurance    Petrol  5 Seats  42,891 Kms
# 1415          Feb 2019  Third Party insurance    Diesel  5 Seats  59,100 Kms
# 1416          Aug 2018          Not Available    Petrol  5 Seats  55,913 Kms
# 1417          Aug 2017          Comprehensive    Diesel  5 Seats  65,000 Kms
# 1418          Oct 2019          Comprehensive    Diesel  5 Seats  60,000 Kms
#
# ...

# %% [markdown]
# # new_car_detail
# **code**

# %%
new_car_detail=[]
for i in df["new_car_detail"]:
    temp=ast.literal_eval(i)
    temp.pop("trendingText")
    print(temp)
    new_car_detail.append(pd.DataFrame([temp]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 new_car_detail=[]
# ----> 2 for i in df["new_car_detail"]:
#       3     temp=ast.literal_eval(i)
#       4     temp.pop("trendingText")
#
# NameError: name 'df' is not defined

# %%
new_car_detail

# %%
new_car_detail = pd.concat(new_car_detail, ignore_index=True)

# %%
new_car_detail["city"]="chennai"

# %%
new_car_detail
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %% [markdown]
# # cars final table

# %%
chennai_cars_df = pd.concat([new_car_detail,new_car_overview,new_car_specs,new_car_feature], axis=1)

# %%
pd.set_option('display.max_column',100)

# %%
chennai_cars_df
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
chennai_cars_df.to_csv("chennai_cars_df.csv",index=False)

# %% [markdown]
# # all city cars

# %%
chennai=pd.read_csv("chennai_cars_df.csv")
bangalore=pd.read_csv("bangalore_cars_df.csv")
kolkata=pd.read_csv("kolkata_cars_df.csv")
delhi=pd.read_csv("delhi_cars_df.csv")
jaipur=pd.read_csv("jaipur_cars_df.csv")
hyderabad=pd.read_csv("hyderabad_cars_df.csv")

# %%
chennai["city"]="chennai"
bangalore["city"]="bangalore"
delhi["city"]="delhi"
jaipur["city"]="jaipur"
hyderabad["city"]="hyderabad"
kolkata["city"]="kolkata"

# %%
df=pd.concat([chennai,bangalore,kolkata,delhi,jaipur,hyderabad],axis=0)

# %%
df.to_csv("all_cars.csv",index=False)

# %%
df=pd.read_csv("all_cars.csv")

# %%
df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Diesel        SUV    60,000       Manual        1  1st Owner
# 8365   0  Diesel      Sedan    50,000    Automatic        1  1st Owner
# 8366   0  Diesel      Sedan  1,20,000    Automatic        3  3rd Owner
# 8367   0  Diesel        SUV    50,000    Automatic        2  2nd Owner
# 8368   0  Diesel        MUV  1,00,000       Manual        1  1st Owner
#
#            oem            model  modelYear  centralVariantId  \
# ...
